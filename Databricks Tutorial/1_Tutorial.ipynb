# %% [markdown]
# ### Data Reading JSON

# %%
display(dbutils.fs.ls("/databricks-datasets/"))

# %%
df = spark.table("workspace.databricks_tutorial.drivers")
display(df)

# %% [markdown]
# ### Data Reading

# %%
spark.sql("DESCRIBE EXTENDED workspace.default.big_mart_sales").display()

# %%
df = spark.table("workspace.default.big_mart_sales")
display(df)

# %%
df = (
    spark.read.format("csv")
    .option("inferSchema", "true")
    .option("header", "true")
    .load("abfss://<container>@<storageaccount>.dfs.core.windows.net/path/to/big_mart_sales.csv")
)

# %%
# %sql
DROP CATALOG databricks_tutorials CASCADE;
