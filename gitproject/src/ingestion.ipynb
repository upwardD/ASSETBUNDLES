# %%
# First cell – Create widget at the top of the notebook
dbutils.widgets.text("catalog_name", "ecommerce", "Catalog Name")

# %%
catalog_name = dbutils.widgets.get("catalog_name")
print("Using catalog:", catalog_name)

# %%
df = spark.sql(f"SELECT * FROM {catalog_name}.bronze.brz_brands")
display(df)
