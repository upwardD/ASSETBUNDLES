# %%
# List workspace directories
import os
print("Current:", os.getcwd())
print("\nWorkspace root:")
print(os.listdir("/Workspace"))
print("\nUsers directory:")
users_path = "/Workspace/Users"
if os.path.exists(users_path):
    print(os.listdir(users_path))
